# %% [markdown]
# [Open in Colab](https://colab.research.google.com/drive/1aIXWV0tGMUmNYrKpZOykIsPQZuY-BFGT)

# %%
# !pip install requests-html
# Out:
# Requirement already satisfied: requests-html in /usr/local/lib/python3.6/dist-packages (0.10.0)
# Requirement already satisfied: parse in /usr/local/lib/python3.6/dist-packages (from requests-html) (1.12.1)
# Requirement already satisfied: w3lib in /usr/local/lib/python3.6/dist-packages (from requests-html) (1.21.0)
# Requirement already satisfied: bs4 in /usr/local/lib/python3.6/dist-packages (from requests-html) (0.0.1)
# Requirement already satisfied: fake-useragent in /usr/local/lib/python3.6/dist-packages (from requests-html) (0.1.11)
# Requirement already satisfied: pyppeteer>=0.0.14 in /usr/local/lib/python3.6/dist-packages (from requests-html) (0.0.25)
# Requirement already satisfied: requests in /usr/local/lib/python3.6/dist-packages (from requests-html) (2.21.0)
# Requirement already satisfied: pyquery in /usr/local/lib/python3.6/dist-packages (from requests-html) (1.4.1)
# Requirement already satisfied: six>=1.4.1 in /usr/local/lib/python3.6/dist-packages (from w3lib->requests-html) (1.12.0)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.6/dist-packages (from bs4->requests-html) (4.6.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.6/dist-packages (from pyppeteer>=0.0.14->requests-html) (4.28.1)
# Requirement already satisfied: websockets in /usr/local/lib/python3.6/dist-packages (from pyppeteer>=0.0.14->requests-html) (8.1)
# Requirement already satisfied: pyee in /usr/local/lib/python3.6/dist-packages (from pyppeteer>=0.0.14->requests-html) (6.0.0)
# Requirement already satisfied: urllib3 in /usr/local/lib/python3.6/dist-packages (from pyppeteer>=0.0.14->requests-html) (1.24.3)
# Requirement already satisfied: appdirs in /usr/local/lib/python3.6/dist-packages (from pyppeteer>=0.0.14->requests-html) (1.4.3)
# Requirement already satisfied: idna<2.9,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests->requests-html) (2.8)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests->requests-html) (2019.11.28)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests->requests-html) (3.0.4)
# Requirement already satisfied: cssselect>0.7.9 in /usr/local/lib/python3.6/dist-packages (from pyquery->requests-html) (1.1.0)
# Requirement already satisfied: lxml>=2.1 in /usr/local/lib/python3.6/dist-packages (from pyquery->requests-html) (4.2.6)

# %%
import os
import re
import pandas as pd
import requests
from requests_html import HTML
from google.colab import drive

# %%
BASE_DIR = '/content/drive'
PROJECT_BASE_DIR = os.path.join(BASE_DIR, "My Drive", "Scraping", "BoxOfficeMojo")
os.makedirs(PROJECT_BASE_DIR, exist_ok=True)
drive.mount(BASE_DIR)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
RAW_DATA_OUT = os.path.join(PROJECT_BASE_DIR, 'raw.csv')
CLEANED_DATA_OUT = os.path.join(PROJECT_BASE_DIR, 'clean.csv')

# %%
URL = 'https://www.boxofficemojo.com/year/world/2019/'

# %%
r = requests.get(URL)
print(r.status_code) # 200-299 we're good. If 500-599 that's server error. #404 --> HTTP Status CODES
html_doc = r.text
# Out:
# 200

# %%
html = HTML(html=html_doc)

# %%
# html.find(".mojo-gutter", first=True).text # .mojo-gutter

# %%
table = html.find(".imdb-scroll-table", first=True)
# print(table.text)

# %%
rows = table.find("tr")
header = {}
for i, row in enumerate(rows):
  header_cols = row.find('th')
  for sub_i, header_col in enumerate(header_cols):
    text = header_col.text
    if sub_i == 4:
      text = f"Domestic {text}"
    if sub_i == 6:
       text = f"Foreign {text}"
    header[sub_i] = text
print(header)
# Out:
# {0: 'Rank', 1: 'Release Group', 2: 'Worldwide', 3: 'Domestic', 4: 'Domestic %', 5: 'Foreign', 6: 'Foreign %'}

# %%
all_row_data = []
for i, row in enumerate(rows):
  cols = row.find("td")
  row_data = {}
  for sub_i, col in enumerate(cols):
    col_name = header[sub_i]
    row_data[col_name] = col.text
  all_row_data.append(row_data)

print(all_row_data)
# Out:
# [{}, {'Rank': '1', 'Release Group': 'Avengers: Endgame', 'Worldwide': '$2,797,800,564', 'Domestic': '$858,373,000', 'Domestic %': '30.7%', 'Foreign': '$1,939,427,564', 'Foreign %': '69.3%'}, {'Rank': '2', 'Release Group': 'The Lion King', 'Worldwide': '$1,656,405,082', 'Domestic': '$543,638,043', 'Domestic %': '32.8%', 'Foreign': '$1,112,767,039', 'Foreign %': '67.2%'}, {'Rank': '3', 'Release Group': 'Spider-Man: Far from Home', 'Worldwide': '$1,131,927,996', 'Domestic': '$390,532,085', 'Domestic %': '34.5%', 'Foreign': '$741,395,911', 'Foreign %': '65.5%'}, {'Rank': '4', 'Release Group': 'Captain Marvel', 'Worldwide': '$1,128,274,794', 'Domestic': '$426,829,839', 'Domestic %': '37.8%', 'Foreign': '$701,
# %%
df = pd.DataFrame(all_row_data)
df.head()
df.to_csv(RAW_DATA_OUT, index=False)

# %%
df.set_index("Rank", inplace=True)
df.dropna(inplace=True)
df.head(n=10)
# Out:
#                               Release Group  ... Foreign %
# Rank                                         ...
# 1                         Avengers: Endgame  ...     69.3%
# 2                             The Lion King  ...     67.2%
# 3                 Spider-Man: Far from Home  ...     65.5%
# 4                            Captain Marvel  ...     62.2%
# 5                               Toy Story 4  ...     59.6%
# 6                                     Joker  ...     68.5%
# 7                                   Aladdin  ...     66.2%
# 8                                 Frozen II  ...       63%
# 9     Fast & Furious Presents: Hobbs & Shaw  ...     77.1%
# 10                                   Ne Zha  ...     99.5%
#
# [10 rows x 6 columns]

# %%
df['currency'] = 'USD'
df.head()
# Out:
#                   Release Group       Worldwide  ... Foreign % currency
# Rank                                             ...
# 1             Avengers: Endgame  $2,797,800,564  ...     69.3%      USD
# 2                 The Lion King  $1,656,405,082  ...     67.2%      USD
# 3     Spider-Man: Far from Home  $1,131,927,996  ...     65.5%      USD
# 4                Captain Marvel  $1,128,274,794  ...     62.2%      USD
# 5                   Toy Story 4  $1,073,394,593  ...     59.6%      USD
#
# [5 rows x 7 columns]

# %%
# df['Domestic'] = df['Domestic'].astype(int)
df.fillna(0, inplace=True)

# %%
def currency_to_int(currency_str):
  if isinstance(currency_str, int):
    return currency_str
  pattern = r'[^\d.]'
  amount = re.sub(pattern, '', currency_str)
  if amount == "":
    return 0
  return amount

# %%
cols_to_clean = ['Worldwide', 'Domestic', 'Foreign']
def clean_row_data(row, *args, **kwargs):
  for col in cols_to_clean:
    row[col] = currency_to_int(row[col])
  return row

df.apply(clean_row_data, axis=1)

df.head(n=10)
# Out:
#                               Release Group   Worldwide  ... Foreign % currency
# Rank                                                     ...
# 1                         Avengers: Endgame  2797800564  ...     69.3%      USD
# 2                             The Lion King  1656405082  ...     67.2%      USD
# 3                 Spider-Man: Far from Home  1131927996  ...     65.5%      USD
# 4                            Captain Marvel  1128274794  ...     62.2%      USD
# 5                               Toy Story 4  1073394593  ...     59.6%      USD
# 6                                     Joker  1055973580  ...     68.5%      USD
# 7                                   Aladdin  1050693953  ...     66.2%      USD
# 8                                 Frozen II   927920321  ...       63%      USD
# 9     Fast & Furious Presents: Hobbs & Shaw   758910100  ...     77.1%      USD
# 10                                   Ne Zha   700547754  ...     99.5%      USD
#
# [10 rows x 7 columns]

# %%
for col in cols_to_clean:
  df[col] = df[col].astype(int) 

df.dtypes
# Out:
# Release Group    object
# Worldwide         int64
# Domestic          int64
# Domestic %       object
# Foreign           int64
# Foreign %        object
# currency         object
# dtype: object

# %%
df.to_csv(CLEANED_DATA_OUT, index=True)

# %%
final_df = pd.read_csv(CLEANED_DATA_OUT)
final_df.set_index("Rank", inplace=True)
final_df.dtypes
# Out:
# Release Group    object
# Worldwide         int64
# Domestic          int64
# Domestic %       object
# Foreign           int64
# Foreign %        object
# currency         object
# dtype: object
